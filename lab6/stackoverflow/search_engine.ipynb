# %%
from data_manager import Vector, TruncatedMatrix
import json
import pickle
from math import log10 as log
import numpy as np
from scipy import sparse
from sklearn.decomposition import TruncatedSVD

# %%
with open("data/alphabet.json", "r", encoding="latin-1") as f:
    alphabet = json.load(f)

# %%
vectors: list[Vector] = []
with open("data/Bag_of_words.pickle", "rb") as f:
    while True:
        try:
            vectors.append(pickle.load(f))
        except EOFError:
            break

# %%
N = len(vectors)
M = len(alphabet)
print(M, N)
# Out:
# 97308 182513

# %%
word_frequency = {}
for word in alphabet:
    word_frequency[word] = 0

for vec in vectors:
    for word in vec.vector:
        word_frequency[word] += 1

idf = {}
for word in word_frequency:
    idf[word] = log(N / word_frequency[word])

# %%
def create_sparse_matrix(filename="sparse_matrix.npz", use_idf=False):
    no_of_entries = 0
    for v in vectors:
        no_of_entries += len(v.vector)

    data = np.array([0 for _ in range(no_of_entries)], dtype=float)
    row = np.array([0 for _ in range(no_of_entries)], dtype=int)
    col = np.copy(row)

    ind = 0
    for i, v in enumerate(vectors):
        start = ind
        for w in v.vector:
            data[ind] = v.vector[w] * (idf[w] if use_idf else 1)
            row[ind] = alphabet[w]
            col[ind] = i
            ind += 1
        data[start:ind] /= np.linalg.norm(data[start:ind])

    matrix_to_save = sparse.csr_matrix((data, (row, col)), shape=(M, N), dtype=float)
    sparse.save_npz(f"data/matrices/{filename}", matrix_to_save)

# %%
create_sparse_matrix()

# %%
create_sparse_matrix("sparse_matrix_idf.npz", use_idf=True)

# %%
matrix = sparse.load_npz("data/matrices/sparse_matrix.npz")
matrix_idf = sparse.load_npz("data/matrices/sparse_matrix_idf.npz")

# %%
def save_truncated_svd(truncation_level):
    svd = TruncatedSVD(truncation_level).fit(matrix_idf)
    u_s = svd.transform(matrix_idf)
    sigma = svd.singular_values_
    v = svd.components_
    vector_lengths = np.linalg.norm(np.diag(sigma) @ v, axis=0)
    svd_truncation_level = TruncatedMatrix(truncation_level, u_s, sigma, v, vector_lengths)
    with open(f"data/matrices/svd_matrix_{truncation_level}.pickle", "wb") as file:
        pickle.dump(svd_truncation_level, file)

# %%
def load_truncated_svd(truncation_level):
    with open(f"data/matrices/svd_matrix_{truncation_level}.pickle", "rb") as file:
        svd = pickle.load(file)
    return svd

# %%
# %%time
save_truncated_svd(20)
# Out:
# CPU times: total: 26.3 s
# Wall time: 32.6 s

# %%
# %%time
save_truncated_svd(50)
# Out:
# CPU times: total: 49.3 s
# Wall time: 55.8 s

# %%
# %%time
save_truncated_svd(100)
# Out:
# CPU times: total: 1min 30s
# Wall time: 1min 38s

# %%
# %%time
save_truncated_svd(200)
# Out:
# CPU times: total: 2min 15s
# Wall time: 2min 13s

# %%
# %%time
save_truncated_svd(400)
# Out:
# CPU times: total: 4min 4s
# Wall time: 3min 33s

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.probability import FreqDist
from string import punctuation
from math import sqrt

stop_words = set([word.lower() for word in stopwords.words('english')])
snowball_stemmer = SnowballStemmer('english')

def normalize_vector(vector):
    length = 0
    for w in vector:
        length += vector[w]**2
    length = sqrt(length)
    for w in vector:
        vector[w] /= length
    return vector

def process_text(text: str) -> dict[str, int]:
    text = "".join(list(map(lambda c: " " if c in punctuation else c, text)))
    words = [w.lower() for sentence in sent_tokenize(text) for w in word_tokenize(sentence)]
    words = [w for w in words if w not in stop_words]
    words = [snowball_stemmer.stem(w) for w in words]
    words = [w for w in words if w in alphabet]
    return normalize_vector(dict(FreqDist(words)))

# %%
def convert_to_sparse(query):
    data = np.array([0 for _ in range(len(query))], dtype=float)
    row = np.array([0 for _ in range(len(query))], dtype=int)
    col = np.copy(row)
    ind = 0
    for w in query:
        data[ind] = query[w]
        col[ind] = alphabet[w]
        ind += 1

    return sparse.csr_matrix((data, (row, col)), shape=(1, M), dtype=float)

def k_best_vectors(vector: sparse.csr_matrix):
    best_values = np.sort(vector.todense(), axis=1)[:, ::-1]
    best_indices = np.argsort(vector.todense(), axis=1)[:, ::-1]
    return [(best_indices[0, i], best_values[0, i]) for i in range(k)]

def find_closest_vectors(query):
    sparse_query = convert_to_sparse(query)
    return k_best_vectors(np.abs(sparse_query @ matrix))

def find_closest_vectors_idf(query):
    sparse_query = convert_to_sparse(query)
    return k_best_vectors(np.abs(sparse_query @ matrix_idf))

# %%
def convert_to_dense(query):
    data = np.array([0 for _ in range(M)], dtype=float)
    for w in query:
        data[alphabet[w]] = query[w]
    return data

def find_closest_vectors_svd(query, svd: TruncatedMatrix):
    dense_query = convert_to_dense(query)
    best = np.abs(((dense_query @ svd.U_S) @ svd.V) / svd.vector_lengths)
    return list(zip(np.argsort(best)[::-1][:k], np.sort(best)[::-1][:k]))

# %%
def print_answers(query_text, function, *args):
    q = process_text(query_text)
    res = function(q, *args)
    url = "https://stackoverflow.com/questions/"
    for i, (ind, angle) in enumerate(res):
        print(f"Result number: {i + 1}")
        print(f"Absolut value of angle between query and result: {angle}")
        print(f"Question: {vectors[ind].question_title}")
        print(f"Question site url: {url}{vectors[ind].question_id}")
        print("--------------------------------------")

# %%
k = 100

# %%
question = "What are generators"

# %%
print_answers(question, find_closest_vectors_idf)
# Out:
# Result number: 1
# Absolut value of angle between query and result: 0.31333871876767555
# Question: Python optimization through bytecode
# Question site url: https://stackoverflow.com/questions/20940935
# --------------------------------------
# Result number: 2
# Absolut value of angle between query and result: 0.25668561660644856
# Question: How to validate Python bytecode?
# Question site url: https://stackoverflow.com/questions/23267970
# --------------------------------------
# Result number: 3
# Absolut value of angle between query and result: 0.25199111924524653
# Question: Python bytecode and .pyc file format specification
# Question site url: https://stackoverflow.com/questions/35229387
# --------------------------------------
# Result number: 4
# Absolut value of angle between query and result: 0.24871896548908304
# Question: Debugging python bytecode when source is not available
# Question site url: https://stackoverflow.com/questions/32486204
# --------------------------------------
# Result number: 5
# Absolut value of angle between query and result: 0.24191129743022374
# Question: What does it mean when people say CPython is written in C?
# Question site url: https://stackoverflow.com/questions/17400805
# --------------------------------------
# Result number: 6
# Absolut value of angle between query and result: 0.23937669523172514
# Question: Python bytecode generated when multiprocessing Pool is called
# Question site url: https://stackoverflow.com/questions/21919563
# --------------------------------------
# Result number: 7
# Absolut value of angle between query and result: 0.23571447690546654
# Question: Given a python .pyc file, is there a tool that let me view the bytecode?
# Question site url: https://stackoverflow.com/questions/11141387
# --------------------------------------
# Result number: 8
# Absolut value of angle between query and result: 0.23337115204914047
# Question: Is it easy to fully decompile python compiled(*.pyc) files?
# Question site url: https://stackoverflow.com/questions/3464326
# --------------------------------------
# Result number: 9
# Absolut value of angle between query and result: 0.23294069753344393
# Question: Create Python bytecode from list of opcodes and arguments?
# Question site url: https://stackoverflow.com/questions/8972144
# --------------------------------------
# Result number: 10
# Absolut value of angle between query and result: 0.2141813843608605
# Question: What is the main use of the Python built-in 'compile'?
# Question site url: https://stackoverflow.com/questions/17901080
# --------------------------------------
# Result number: 11
# Absolut value of angle between query and result: 0.21344150143433085
# Question: Some python / numpy optimization possible?
# Question site url: https://stackoverflow.com/questions/20055067
# --------------------------------------
# Result number: 12
# Absolut value of angle between query and result: 0.20390525337062793
# Question: How exactly does a python (django) request happen? does it have to reparse all the codebase?
# Question site url: https://stackoverflow.com/questions/3018690
# --------------------------------------
# Result number: 13
# Absolut value of angle between query and result: 0.19936948298546486
# Question: CPython is bytecode interpreter?
# Question site url: https://stackoverflow.com/questions/1644619
# --------------------------------------
# Result number: 14
# Absolut value of angle between query and result: 0.1966335276172146
# Question: Python numpy.random.normal only positive values
# Question site url: https://stackoverflow.com/questions/16312006
# --------------------------------------
# Result number: 15
# Absolut value of angle between query and result: 0.1965642517563748
# Question: Why python compile the source to bytecode before interpreting?
# Question site url: https://stackoverflow.com/questions/888100
# --------------------------------------
# Result number: 16
# Absolut value of angle between query and result: 0.19513272906602253
# Question: How exactly is Python Bytecode Run in CPython?
# Question site url: https://stackoverflow.com/questions/19916729
# --------------------------------------
# Result number: 17
# Absolut value of angle between query and result: 0.18908220633937017
# Question: Difference between loading time and running time in python?
# Question site url: https://stackoverflow.com/questions/6803126
# --------------------------------------
# Result number: 18
# Absolut value of angle between query and result: 0.18859734250282154
# Question: Why does Python provide locking mechanisms if it's subject to a GIL?
# Question site url: https://stackoverflow.com/questions/26873512
# --------------------------------------
# Result number: 19
# Absolut value of angle between query and result: 0.1877696945104041
# Question: Python Practices To Enforce Bytecode Compilation? (.pyc)
# Question site url: https://stackoverflow.com/questions/6963695
# --------------------------------------
# Result number: 20
# Absolut value of angle between query and result: 0.1725540037694552
# Question: How to read python bytecode?
# Question site url: https://stackoverflow.com/questions/19560057
# --------------------------------------
# Result number: 21
# Absolut value of angle between query and result: 0.1692665106677204
# Question: Which is faster?
# Question site url: https://stackoverflow.com/questions/3047799
# --------------------------------------
# Result number: 22
# Absolut value of angle between query and result: 0.16378676877234788
# Question: Is Python interpreted (like Javascript or PHP)?
# Question site url: https://stackoverflow.com/questions/745743
# --------------------------------------
# Result number: 23
# Absolut value of angle between query and result: 0.16327531878178833
# Question: Cythonize two small numpy functions, help needed
# Question site url: https://stackoverflow.com/questions/20074780
# --------------------------------------
# Result number: 24
# Absolut value of angle between query and result: 0.1629977041033843
# Question: normality test of a distribution in python
# Question site url: https://stackoverflow.com/questions/22179119
# --------------------------------------
# Result number: 25
# Absolut value of angle between query and result: 0.16297992712952297
# Question: C++ or Python for an Extensive Math Program?
# Question site url: https://stackoverflow.com/questions/11625450
# --------------------------------------
# Result number: 26
# Absolut value of angle between query and result: 0.16092045647114786
# Question: If Python is interpreted, what are .pyc files?
# Question site url: https://stackoverflow.com/questions/2998215
# --------------------------------------
# Result number: 27
# Absolut value of angle between query and result: 0.16051201521318134
# Question: Putting a function to a local namespace to speeding up access taking descriptors into account
# Question site url: https://stackoverflow.com/questions/8377460
# --------------------------------------
# Result number: 28
# Absolut value of angle between query and result: 0.15976852868808514
# Question: Numpy normalization code is strangely slow
# Question site url: https://stackoverflow.com/questions/20308305
# --------------------------------------
# Result number: 29
# Absolut value of angle between query and result: 0.15862906250257108
# Question: Will changes made to a Python script affect another run in progress on the same file?
# Question site url: https://stackoverflow.com/questions/31077719
# --------------------------------------
# Result number: 30
# Absolut value of angle between query and result: 0.15778413369356306
# Question: Something like __pycache__ for Python 2.x?
# Question site url: https://stackoverflow.com/questions/37467733
# --------------------------------------
# Result number: 31
# Absolut value of angle between query and result: 0.15129178142381866
# Question: Python 2 and 3, are the bytecode (pyo & pyc) backward compatible?
# Question site url: https://stackoverflow.com/questions/10547099
# --------------------------------------
# Result number: 32
# Absolut value of angle between query and result: 0.1487930488432098
# Question: What do the zeros in python function bytecode mean?
# Question site url: https://stackoverflow.com/questions/25083861
# --------------------------------------
# Result number: 33
# Absolut value of angle between query and result: 0.1487140758605653
# Question: Is it possible to get python bytecode without using co_code?
# Question site url: https://stackoverflow.com/questions/12513901
# --------------------------------------
# Result number: 34
# Absolut value of angle between query and result: 0.14791401223709605
# Question: How to convert path to Mac OS X path, the almost-NFD normal form?
# Question site url: https://stackoverflow.com/questions/18137554
# --------------------------------------
# Result number: 35
# Absolut value of angle between query and result: 0.14749445112597231
# Question: Is code interpreted at every call in Web2Py?
# Question site url: https://stackoverflow.com/questions/3649607
# --------------------------------------
# Result number: 36
# Absolut value of angle between query and result: 0.1468498249382643
# Question: How to get calling expression when tracing a Python function?
# Question site url: https://stackoverflow.com/questions/13952022
# --------------------------------------
# Result number: 37
# Absolut value of angle between query and result: 0.14539586418285377
# Question: Fuzzy string matching in Python
# Question site url: https://stackoverflow.com/questions/38969383
# --------------------------------------
# Result number: 38
# Absolut value of angle between query and result: 0.14508113616220958
# Question: Is there an easy way to get all common module extensions?
# Question site url: https://stackoverflow.com/questions/27569690
# --------------------------------------
# Result number: 39
# Absolut value of angle between query and result: 0.14276276365430995
# Question: P value for Normality test very small despite normal histogram
# Question site url: https://stackoverflow.com/questions/39706242
# --------------------------------------
# Result number: 40
# Absolut value of angle between query and result: 0.1418959246147522
# Question: Print web page source code in python
# Question site url: https://stackoverflow.com/questions/20299088
# --------------------------------------
# Result number: 41
# Absolut value of angle between query and result: 0.1405773026605789
# Question: how to normalize array numpy?
# Question site url: https://stackoverflow.com/questions/21030391
# --------------------------------------
# Result number: 42
# Absolut value of angle between query and result: 0.13957417843290654
# Question: What is function.__code__ behavior across multiple program executions?
# Question site url: https://stackoverflow.com/questions/36278084
# --------------------------------------
# Result number: 43
# Absolut value of angle between query and result: 0.13956117496089454
# Question: python os.path.isdir() is slow on windows
# Question site url: https://stackoverflow.com/questions/5316928
# --------------------------------------
# Result number: 44
# Absolut value of angle between query and result: 0.13857635130652116
# Question: List indices must be integers, not tuple
# Question site url: https://stackoverflow.com/questions/29986235
# --------------------------------------
# Result number: 45
# Absolut value of angle between query and result: 0.13850357806476413
# Question: Normalize PCA with scikit-learn when data is split
# Question site url: https://stackoverflow.com/questions/27646915
# --------------------------------------
# Result number: 46
# Absolut value of angle between query and result: 0.1377520737036202
# Question: Why can't I normalize this random unicode string?
# Question site url: https://stackoverflow.com/questions/14401703
# --------------------------------------
# Result number: 47
# Absolut value of angle between query and result: 0.13758888931709806
# Question: Is there a possibility to override a unary operator with a binary one in Python?
# Question site url: https://stackoverflow.com/questions/32806796
# --------------------------------------
# Result number: 48
# Absolut value of angle between query and result: 0.1375637077063073
# Question: Import arbitrary-named file as a Python module, without generating bytecode file
# Question site url: https://stackoverflow.com/questions/6811902
# --------------------------------------
# Result number: 49
# Absolut value of angle between query and result: 0.13753339181888663
# Question: If Python is executed one line at a time, why can it see variables before they're declared?
# Question site url: https://stackoverflow.com/questions/19171477
# --------------------------------------
# Result number: 50
# Absolut value of angle between query and result: 0.13687527001487873
# Question: What are the implications of running python with the optimize flag?
# Question site url: https://stackoverflow.com/questions/2830358
# --------------------------------------
# Result number: 51
# Absolut value of angle between query and result: 0.13359634281345864
# Question: Difference between ACTIVE and NORMAL state
# Question site url: https://stackoverflow.com/questions/19125342
# --------------------------------------
# Result number: 52
# Absolut value of angle between query and result: 0.13325353369097592
# Question: Are Python inner functions compiled?
# Question site url: https://stackoverflow.com/questions/6020532
# --------------------------------------
# Result number: 53
# Absolut value of angle between query and result: 0.13304229215765662
# Question: Normalizing A Numpy Arange
# Question site url: https://stackoverflow.com/questions/31104619
# --------------------------------------
# Result number: 54
# Absolut value of angle between query and result: 0.13260969948864001
# Question: how to encrypt python source code?
# Question site url: https://stackoverflow.com/questions/6578452
# --------------------------------------
# Result number: 55
# Absolut value of angle between query and result: 0.13189120682914238
# Question: Which form of unicode normalization is appropriate for text mining?
# Question site url: https://stackoverflow.com/questions/11233286
# --------------------------------------
# Result number: 56
# Absolut value of angle between query and result: 0.13072091682228557
# Question: Why does Python only save the bytecode for a script if it is imported?
# Question site url: https://stackoverflow.com/questions/32447695
# --------------------------------------
# Result number: 57
# Absolut value of angle between query and result: 0.12949147041884018
# Question: In python, why is s*3 faster than s+s+s?
# Question site url: https://stackoverflow.com/questions/31295017
# --------------------------------------
# Result number: 58
# Absolut value of angle between query and result: 0.1289588748560364
# Question: How to model particle bouncing off of a curved surface in 3D?
# Question site url: https://stackoverflow.com/questions/31058446
# --------------------------------------
# Result number: 59
# Absolut value of angle between query and result: 0.1288938753102294
# Question: How does variable swapping work internally?
# Question site url: https://stackoverflow.com/questions/8587236
# --------------------------------------
# Result number: 60
# Absolut value of angle between query and result: 0.1288001537376367
# Question: Assembling Bytecode - PyCode New
# Question site url: https://stackoverflow.com/questions/13251882
# --------------------------------------
# Result number: 61
# Absolut value of angle between query and result: 0.1281965677522466
# Question: What is the precedence of python compiled files in imports?
# Question site url: https://stackoverflow.com/questions/6584457
# --------------------------------------
# Result number: 62
# Absolut value of angle between query and result: 0.1281226335679857
# Question: Can somone explain how unicodedata.normalize(form, unistr) work with examples?
# Question site url: https://stackoverflow.com/questions/14682397
# --------------------------------------
# Result number: 63
# Absolut value of angle between query and result: 0.12768494579712097
# Question: What is the meaning of True == True != False in Python and how to find out?
# Question site url: https://stackoverflow.com/questions/18528431
# --------------------------------------
# Result number: 64
# Absolut value of angle between query and result: 0.12742652187030018
# Question: How is Python itertools `constant_factory` example superior to `lambda : x`?
# Question site url: https://stackoverflow.com/questions/27532243
# --------------------------------------
# Result number: 65
# Absolut value of angle between query and result: 0.1269631696941732
# Question: How does List Comprehension exactly work in Python?
# Question site url: https://stackoverflow.com/questions/38941643
# --------------------------------------
# Result number: 66
# Absolut value of angle between query and result: 0.1265264483267775
# Question: Method to convert object from class to subclass in Python
# Question site url: https://stackoverflow.com/questions/33803725
# --------------------------------------
# Result number: 67
# Absolut value of angle between query and result: 0.12593968812891984
# Question: What do the python file extensions, .pyc .pyd .pyo stand for?
# Question site url: https://stackoverflow.com/questions/8822335
# --------------------------------------
# Result number: 68
# Absolut value of angle between query and result: 0.1258464538151356
# Question: How to acquire Abstract Syntax Tree from ParseResults
# Question site url: https://stackoverflow.com/questions/33571800
# --------------------------------------
# Result number: 69
# Absolut value of angle between query and result: 0.12476535647032325
# Question: Why is the 'running' of .pyc files not faster compared to .py files?
# Question site url: https://stackoverflow.com/questions/16773362
# --------------------------------------
# Result number: 70
# Absolut value of angle between query and result: 0.1229574144877496
# Question: Python Compilation/Interpretation Process
# Question site url: https://stackoverflow.com/questions/3299648
# --------------------------------------
# Result number: 71
# Absolut value of angle between query and result: 0.12284371711838248
# Question: Python difference between randn and normal
# Question site url: https://stackoverflow.com/questions/21738383
# --------------------------------------
# Result number: 72
# Absolut value of angle between query and result: 0.12095608254662933
# Question: Good way to implement a normalize filter in numpy
# Question site url: https://stackoverflow.com/questions/21382521
# --------------------------------------
# Result number: 73
# Absolut value of angle between query and result: 0.12026823965657711
# Question: Embedding a Low Performance Scripting Language in Python
# Question site url: https://stackoverflow.com/questions/5099043
# --------------------------------------
# Result number: 74
# Absolut value of angle between query and result: 0.11991999434681493
# Question: Is there a way to retrieve source code from a live Python interpreter session or a dynamically created object?
# Question site url: https://stackoverflow.com/questions/11497049
# --------------------------------------
# Result number: 75
# Absolut value of angle between query and result: 0.1192410930062199
# Question: PIL not rendering fonts uniformly across machines
# Question site url: https://stackoverflow.com/questions/1449663
# --------------------------------------
# Result number: 76
# Absolut value of angle between query and result: 0.11821403086863638
# Question: Normalization in sci-kit learn linear_models
# Question site url: https://stackoverflow.com/questions/33246316
# --------------------------------------
# Result number: 77
# Absolut value of angle between query and result: 0.11787058568924538
# Question: Eclipse + Django: How to get bytecode output when python source files change?
# Question site url: https://stackoverflow.com/questions/3031383
# --------------------------------------
# Result number: 78
# Absolut value of angle between query and result: 0.11711497107744173
# Question: `sys.dont_write_bytecode` is True, but .pyc files are still generated
# Question site url: https://stackoverflow.com/questions/9917889
# --------------------------------------
# Result number: 79
# Absolut value of angle between query and result: 0.11650626602746525
# Question: compiler vs interpreter ( on basis of construction and design )
# Question site url: https://stackoverflow.com/questions/8203221
# --------------------------------------
# Result number: 80
# Absolut value of angle between query and result: 0.11625146202014303
# Question: Does calling random.normal on an array of values add noise?
# Question site url: https://stackoverflow.com/questions/31128510
# --------------------------------------
# Result number: 81
# Absolut value of angle between query and result: 0.11591645236985985
# Question: How can I parse an arff file without using external libraries in Python
# Question site url: https://stackoverflow.com/questions/22187589
# --------------------------------------
# Result number: 82
# Absolut value of angle between query and result: 0.11585082790162254
# Question: Why is IronPython faster than the Official Python Interpreter
# Question site url: https://stackoverflow.com/questions/504716
# --------------------------------------
# Result number: 83
# Absolut value of angle between query and result: 0.11476505508629155
# Question: Python list() vs list comprehension building speed
# Question site url: https://stackoverflow.com/questions/29356846
# --------------------------------------
# Result number: 84
# Absolut value of angle between query and result: 0.11468786695039769
# Question: How to rewrite a specific frame in a traceback?
# Question site url: https://stackoverflow.com/questions/8181532
# --------------------------------------
# Result number: 85
# Absolut value of angle between query and result: 0.11393994570196464
# Question: Reassembling Python bytecode to the original code?
# Question site url: https://stackoverflow.com/questions/2124202
# --------------------------------------
# Result number: 86
# Absolut value of angle between query and result: 0.11347971748776496
# Question: Right function for normalizing input of sklearn SVM
# Question site url: https://stackoverflow.com/questions/30918781
# --------------------------------------
# Result number: 87
# Absolut value of angle between query and result: 0.11337201103507628
# Question: Why does setuptools need to write bytecode?
# Question site url: https://stackoverflow.com/questions/15207938
# --------------------------------------
# Result number: 88
# Absolut value of angle between query and result: 0.11335903101203593
# Question: Is byte-compiling Python platform-specific?
# Question site url: https://stackoverflow.com/questions/33425899
# --------------------------------------
# Result number: 89
# Absolut value of angle between query and result: 0.11323545101785079
# Question: How to generate code objects from modules in Python?
# Question site url: https://stackoverflow.com/questions/2293322
# --------------------------------------
# Result number: 90
# Absolut value of angle between query and result: 0.11301376223424323
# Question: Normalization in the artificial neural network
# Question site url: https://stackoverflow.com/questions/20579179
# --------------------------------------
# Result number: 91
# Absolut value of angle between query and result: 0.11280522307655369
# Question: Can you race condition in Python while there is a GIL?
# Question site url: https://stackoverflow.com/questions/23855138
# --------------------------------------
# Result number: 92
# Absolut value of angle between query and result: 0.11268444746944353
# Question: Python accelerator
# Question site url: https://stackoverflow.com/questions/3619063
# --------------------------------------
# Result number: 93
# Absolut value of angle between query and result: 0.1116330280512829
# Question: Creating new binary columns from single string column in pandas
# Question site url: https://stackoverflow.com/questions/22621716
# --------------------------------------
# Result number: 94
# Absolut value of angle between query and result: 0.11141344498105572
# Question: Python Virtual Machine architecture diagrams/references
# Question site url: https://stackoverflow.com/questions/682675
# --------------------------------------
# Result number: 95
# Absolut value of angle between query and result: 0.11107738043559996
# Question: How does cx_freeze compile a Python script?
# Question site url: https://stackoverflow.com/questions/24443621
# --------------------------------------
# Result number: 96
# Absolut value of angle between query and result: 0.11078519700126091
# Question: How does the python interpreter know when to compile and update a .pyc file?
# Question site url: https://stackoverflow.com/questions/23775760
# --------------------------------------
# Result number: 97
# Absolut value of angle between query and result: 0.1106343875436201
# Question: Python code for determining which normal form tabular data is in
# Question site url: https://stackoverflow.com/questions/2157531
# --------------------------------------
# Result number: 98
# Absolut value of angle between query and result: 0.11060931590740883
# Question: Integration of normal distribution using Simpson's rule
# Question site url: https://stackoverflow.com/questions/20379874
# --------------------------------------
# Result number: 99
# Absolut value of angle between query and result: 0.11010859195489417
# Question: Find a python transformation function or numpy matrix to transform skewed normal distribution to normal distribution
# Question site url: https://stackoverflow.com/questions/38151261
# --------------------------------------
# Result number: 100
# Absolut value of angle between query and result: 0.108676685279216
# Question: python 3.1 - Creating normal distribution
# Question site url: https://stackoverflow.com/questions/4697836
# --------------------------------------

# %%
truncated_idf = load_truncated_svd(200)

# %%
print_answers(question, find_closest_vectors_svd, truncated_idf)
# Out:
# Result number: 1
# Absolut value of angle between query and result: 0.07376743893757974
# Question: Python optimization through bytecode
# Question site url: https://stackoverflow.com/questions/20940935
# --------------------------------------
# Result number: 2
# Absolut value of angle between query and result: 0.0732394107487622
# Question: Is it easy to fully decompile python compiled(*.pyc) files?
# Question site url: https://stackoverflow.com/questions/3464326
# --------------------------------------
# Result number: 3
# Absolut value of angle between query and result: 0.0717861899463477
# Question: What are Python disassemblers used for?
# Question site url: https://stackoverflow.com/questions/18647897
# --------------------------------------
# Result number: 4
# Absolut value of angle between query and result: 0.07112096289087391
# Question: Difference between loading time and running time in python?
# Question site url: https://stackoverflow.com/questions/6803126
# --------------------------------------
# Result number: 5
# Absolut value of angle between query and result: 0.06733236759231871
# Question: How exactly is Python Bytecode Run in CPython?
# Question site url: https://stackoverflow.com/questions/19916729
# --------------------------------------
# Result number: 6
# Absolut value of angle between query and result: 0.066469022596798
# Question: Why does Python handle '1 is 1**2' differently from '1000 is 10**3'?
# Question site url: https://stackoverflow.com/questions/21880308
# --------------------------------------
# Result number: 7
# Absolut value of angle between query and result: 0.06597491234914236
# Question: What is faster, `if x` or `if x != 0`?
# Question site url: https://stackoverflow.com/questions/38172499
# --------------------------------------
# Result number: 8
# Absolut value of angle between query and result: 0.06543632925249324
# Question: Why python compile the source to bytecode before interpreting?
# Question site url: https://stackoverflow.com/questions/888100
# --------------------------------------
# Result number: 9
# Absolut value of angle between query and result: 0.06436708829958118
# Question: CPython is bytecode interpreter?
# Question site url: https://stackoverflow.com/questions/1644619
# --------------------------------------
# Result number: 10
# Absolut value of angle between query and result: 0.06394472387223415
# Question: Why is the 'running' of .pyc files not faster compared to .py files?
# Question site url: https://stackoverflow.com/questions/16773362
# --------------------------------------
# Result number: 11
# Absolut value of angle between query and result: 0.06386045861397792
# Question: How to generate code objects from modules in Python?
# Question site url: https://stackoverflow.com/questions/2293322
# --------------------------------------
# Result number: 12
# Absolut value of angle between query and result: 0.06371575888670439
# Question: Is this calculation executed in Python?
# Question site url: https://stackoverflow.com/questions/28200121
# --------------------------------------
# Result number: 13
# Absolut value of angle between query and result: 0.06349476285516177
# Question: Why `float` function is slower than multiplying by 1.0?
# Question site url: https://stackoverflow.com/questions/22983625
# --------------------------------------
# Result number: 14
# Absolut value of angle between query and result: 0.063287943872257
# Question: When does python compile the constant string letters, to combine the constant strings to one constant string
# Question site url: https://stackoverflow.com/questions/14493236
# --------------------------------------
# Result number: 15
# Absolut value of angle between query and result: 0.06314262472894139
# Question: If Python is interpreted, what are .pyc files?
# Question site url: https://stackoverflow.com/questions/2998215
# --------------------------------------
# Result number: 16
# Absolut value of angle between query and result: 0.06313135833665798
# Question: Disassemble python byte-code
# Question site url: https://stackoverflow.com/questions/37106786
# --------------------------------------
# Result number: 17
# Absolut value of angle between query and result: 0.062324014991310524
# Question: Given a python .pyc file, is there a tool that let me view the bytecode?
# Question site url: https://stackoverflow.com/questions/11141387
# --------------------------------------
# Result number: 18
# Absolut value of angle between query and result: 0.06184599429527764
# Question: Why does Python's dis dislike lists?
# Question site url: https://stackoverflow.com/questions/10473744
# --------------------------------------
# Result number: 19
# Absolut value of angle between query and result: 0.06183273976502602
# Question: is there any kind of performance gain while using .pyc files in python?
# Question site url: https://stackoverflow.com/questions/9485905
# --------------------------------------
# Result number: 20
# Absolut value of angle between query and result: 0.061675475758279905
# Question: Can compile function output be used to detect changes in the source code
# Question site url: https://stackoverflow.com/questions/38007884
# --------------------------------------
# Result number: 21
# Absolut value of angle between query and result: 0.06165138050217778
# Question: Bytecode optimization
# Question site url: https://stackoverflow.com/questions/37737740
# --------------------------------------
# Result number: 22
# Absolut value of angle between query and result: 0.06142620918972252
# Question: How many CPU cycles one addition take?
# Question site url: https://stackoverflow.com/questions/36338296
# --------------------------------------
# Result number: 23
# Absolut value of angle between query and result: 0.06110429959307283
# Question: Python bytecode and .pyc file format specification
# Question site url: https://stackoverflow.com/questions/35229387
# --------------------------------------
# Result number: 24
# Absolut value of angle between query and result: 0.06095917067052282
# Question: Why is integer divisions not optimised when compiling to bytecode?
# Question site url: https://stackoverflow.com/questions/23031282
# --------------------------------------
# Result number: 25
# Absolut value of angle between query and result: 0.060625984236891674
# Question: How do I disassemble a Python script?
# Question site url: https://stackoverflow.com/questions/869586
# --------------------------------------
# Result number: 26
# Absolut value of angle between query and result: 0.06059504385964368
# Question: Exploring and decompiling python bytecode
# Question site url: https://stackoverflow.com/questions/1149513
# --------------------------------------
# Result number: 27
# Absolut value of angle between query and result: 0.060572032827963994
# Question: Is Python interpreted (like Javascript or PHP)?
# Question site url: https://stackoverflow.com/questions/745743
# --------------------------------------
# Result number: 28
# Absolut value of angle between query and result: 0.06054999960568312
# Question: Reassembling Python bytecode to the original code?
# Question site url: https://stackoverflow.com/questions/2124202
# --------------------------------------
# Result number: 29
# Absolut value of angle between query and result: 0.06039653545234113
# Question: Can Python optimize this simple variable call?
# Question site url: https://stackoverflow.com/questions/18985320
# --------------------------------------
# Result number: 30
# Absolut value of angle between query and result: 0.060290525093557285
# Question: Why compile Python code?
# Question site url: https://stackoverflow.com/questions/471191
# --------------------------------------
# Result number: 31
# Absolut value of angle between query and result: 0.060220732835390006
# Question: modifying python bytecode
# Question site url: https://stackoverflow.com/questions/33348067
# --------------------------------------
# Result number: 32
# Absolut value of angle between query and result: 0.0600560581418716
# Question: Are simple hardcoded arithmetics cached/compiled away?
# Question site url: https://stackoverflow.com/questions/36105978
# --------------------------------------
# Result number: 33
# Absolut value of angle between query and result: 0.06005337885599446
# Question: Python Practices To Enforce Bytecode Compilation? (.pyc)
# Question site url: https://stackoverflow.com/questions/6963695
# --------------------------------------
# Result number: 34
# Absolut value of angle between query and result: 0.05994875488684618
# Question: How to read python bytecode?
# Question site url: https://stackoverflow.com/questions/19560057
# --------------------------------------
# Result number: 35
# Absolut value of angle between query and result: 0.059920815720585247
# Question: How should I understand the output of dis.dis?
# Question site url: https://stackoverflow.com/questions/12673074
# --------------------------------------
# Result number: 36
# Absolut value of angle between query and result: 0.059631249888714564
# Question: What is a .pyc_dis file?
# Question site url: https://stackoverflow.com/questions/3464145
# --------------------------------------
# Result number: 37
# Absolut value of angle between query and result: 0.05934128902536776
# Question: Weird id result on CPython IntObject
# Question site url: https://stackoverflow.com/questions/25281892
# --------------------------------------
# Result number: 38
# Absolut value of angle between query and result: 0.059114899046760934
# Question: pycompile for python3.2
# Question site url: https://stackoverflow.com/questions/13004034
# --------------------------------------
# Result number: 39
# Absolut value of angle between query and result: 0.05903837772656913
# Question: A question regarding string instance uniqueness in python
# Question site url: https://stackoverflow.com/questions/1150765
# --------------------------------------
# Result number: 40
# Absolut value of angle between query and result: 0.05898659033026743
# Question: Does the Python 3 interpreter have a JIT feature?
# Question site url: https://stackoverflow.com/questions/13034991
# --------------------------------------
# Result number: 41
# Absolut value of angle between query and result: 0.0588315842207802
# Question: Why doesn't 1 + 1 use BINARY_ADD?
# Question site url: https://stackoverflow.com/questions/27833485
# --------------------------------------
# Result number: 42
# Absolut value of angle between query and result: 0.0585045500041445
# Question: Python compiled file generated even though wrong syntax
# Question site url: https://stackoverflow.com/questions/39476828
# --------------------------------------
# Result number: 43
# Absolut value of angle between query and result: 0.05844907765750102
# Question: does python multiplicative expression evaluates faster if finds a zero?
# Question site url: https://stackoverflow.com/questions/3264345
# --------------------------------------
# Result number: 44
# Absolut value of angle between query and result: 0.05834583427672741
# Question: compiler vs interpreter ( on basis of construction and design )
# Question site url: https://stackoverflow.com/questions/8203221
# --------------------------------------
# Result number: 45
# Absolut value of angle between query and result: 0.05826072769311639
# Question: Disabling pyc files in production
# Question site url: https://stackoverflow.com/questions/37669883
# --------------------------------------
# Result number: 46
# Absolut value of angle between query and result: 0.05803404021693997
# Question: Why is slice assignment faster than `list.insert`?
# Question site url: https://stackoverflow.com/questions/12537716
# --------------------------------------
# Result number: 47
# Absolut value of angle between query and result: 0.057964198678070636
# Question: In python, why is s*3 faster than s+s+s?
# Question site url: https://stackoverflow.com/questions/31295017
# --------------------------------------
# Result number: 48
# Absolut value of angle between query and result: 0.05794475354438731
# Question: Is Python interpreted or compiled or both?
# Question site url: https://stackoverflow.com/questions/6889747
# --------------------------------------
# Result number: 49
# Absolut value of angle between query and result: 0.057797226821706425
# Question: Compilers targeting .pyc files?
# Question site url: https://stackoverflow.com/questions/1592347
# --------------------------------------
# Result number: 50
# Absolut value of angle between query and result: 0.05757419609550878
# Question: Does creating functions inside functions have a recurring cost?
# Question site url: https://stackoverflow.com/questions/12431755
# --------------------------------------
# Result number: 51
# Absolut value of angle between query and result: 0.05750797147347831
# Question: What are the implications of running python with the optimize flag?
# Question site url: https://stackoverflow.com/questions/2830358
# --------------------------------------
# Result number: 52
# Absolut value of angle between query and result: 0.05746661474611305
# Question: How can an implementation of a language in the same language be faster than the language?
# Question site url: https://stackoverflow.com/questions/9379560
# --------------------------------------
# Result number: 53
# Absolut value of angle between query and result: 0.05729370882537442
# Question: What is function.__code__ behavior across multiple program executions?
# Question site url: https://stackoverflow.com/questions/36278084
# --------------------------------------
# Result number: 54
# Absolut value of angle between query and result: 0.05705178509022773
# Question: What does it mean when people say CPython is written in C?
# Question site url: https://stackoverflow.com/questions/17400805
# --------------------------------------
# Result number: 55
# Absolut value of angle between query and result: 0.05686514865485481
# Question: python bytecode, the interpreter and virtual machine
# Question site url: https://stackoverflow.com/questions/4147928
# --------------------------------------
# Result number: 56
# Absolut value of angle between query and result: 0.0566645387732324
# Question: Do python list comprehensions get converted to pure C?
# Question site url: https://stackoverflow.com/questions/24482810
# --------------------------------------
# Result number: 57
# Absolut value of angle between query and result: 0.05666451146659727
# Question: Compiled vs. Interpreted Languages
# Question site url: https://stackoverflow.com/questions/3265357
# --------------------------------------
# Result number: 58
# Absolut value of angle between query and result: 0.05664039826237103
# Question: What is more 'pythonic' for 'not'
# Question site url: https://stackoverflow.com/questions/17659303
# --------------------------------------
# Result number: 59
# Absolut value of angle between query and result: 0.056587655607277625
# Question: In which scenario it is useful to use Disassembly on python?
# Question site url: https://stackoverflow.com/questions/2676154
# --------------------------------------
# Result number: 60
# Absolut value of angle between query and result: 0.05658687248152854
# Question: Python efficiency of and vs multiple ifs
# Question site url: https://stackoverflow.com/questions/3533338
# --------------------------------------
# Result number: 61
# Absolut value of angle between query and result: 0.056312324972937956
# Question: Why do C programs require decompilers but python programs dont?
# Question site url: https://stackoverflow.com/questions/3869435
# --------------------------------------
# Result number: 62
# Absolut value of angle between query and result: 0.05628773170209437
# Question: Python timeit not working?
# Question site url: https://stackoverflow.com/questions/5486272
# --------------------------------------
# Result number: 63
# Absolut value of angle between query and result: 0.05620000689813457
# Question: What optimizations does Python do without the -O flags?
# Question site url: https://stackoverflow.com/questions/2038481
# --------------------------------------
# Result number: 64
# Absolut value of angle between query and result: 0.05606691032973205
# Question: How does one use `dis.dis` to analyze performance?
# Question site url: https://stackoverflow.com/questions/19322705
# --------------------------------------
# Result number: 65
# Absolut value of angle between query and result: 0.055993607952349554
# Question: How to validate Python bytecode?
# Question site url: https://stackoverflow.com/questions/23267970
# --------------------------------------
# Result number: 66
# Absolut value of angle between query and result: 0.05582667451097785
# Question: Python performance characteristics
# Question site url: https://stackoverflow.com/questions/1913906
# --------------------------------------
# Result number: 67
# Absolut value of angle between query and result: 0.0557691163200472
# Question: Cost of using 10**9 over 1000000000?
# Question site url: https://stackoverflow.com/questions/34239159
# --------------------------------------
# Result number: 68
# Absolut value of angle between query and result: 0.05556024524056278
# Question: How can I understand a .pyc file content
# Question site url: https://stackoverflow.com/questions/32562163
# --------------------------------------
# Result number: 69
# Absolut value of angle between query and result: 0.05551384137143532
# Question: Measuring the performance difference between pyc and py files
# Question site url: https://stackoverflow.com/questions/33602796
# --------------------------------------
# Result number: 70
# Absolut value of angle between query and result: 0.055463951351122094
# Question: Python 2 and 3, are the bytecode (pyo & pyc) backward compatible?
# Question site url: https://stackoverflow.com/questions/10547099
# --------------------------------------
# Result number: 71
# Absolut value of angle between query and result: 0.05544521134521029
# Question: Why is (python|ruby) interpreted?
# Question site url: https://stackoverflow.com/questions/1805148
# --------------------------------------
# Result number: 72
# Absolut value of angle between query and result: 0.0553801445608918
# Question: Why is if True slower than if 1?
# Question site url: https://stackoverflow.com/questions/18123965
# --------------------------------------
# Result number: 73
# Absolut value of angle between query and result: 0.05521162604260645
# Question: Tuple or list when using 'in' in an 'if' clause?
# Question site url: https://stackoverflow.com/questions/25368337
# --------------------------------------
# Result number: 74
# Absolut value of angle between query and result: 0.05520653106025342
# Question: JUMP_FORWARD or JUMP_ABSOLUTE with IF statement ? Python 2.5
# Question site url: https://stackoverflow.com/questions/16050423
# --------------------------------------
# Result number: 75
# Absolut value of angle between query and result: 0.05513758064800783
# Question: What is the main use of the Python built-in 'compile'?
# Question site url: https://stackoverflow.com/questions/17901080
# --------------------------------------
# Result number: 76
# Absolut value of angle between query and result: 0.05505468270043542
# Question: Higher order functions in Python
# Question site url: https://stackoverflow.com/questions/34457331
# --------------------------------------
# Result number: 77
# Absolut value of angle between query and result: 0.05495848135513891
# Question: Is there a considerable difference between comparing a number to zero with "==" or as a bool?
# Question site url: https://stackoverflow.com/questions/33791271
# --------------------------------------
# Result number: 78
# Absolut value of angle between query and result: 0.05480819898513637
# Question: Why is %s faster than %d for integer substitution in python?
# Question site url: https://stackoverflow.com/questions/27794069
# --------------------------------------
# Result number: 79
# Absolut value of angle between query and result: 0.05466053127384726
# Question: where are operators mapped to magic methods in python?
# Question site url: https://stackoverflow.com/questions/13334218
# --------------------------------------
# Result number: 80
# Absolut value of angle between query and result: 0.054636546122410964
# Question: global vs. local namespace performance difference
# Question site url: https://stackoverflow.com/questions/34713860
# --------------------------------------
# Result number: 81
# Absolut value of angle between query and result: 0.05463342199726114
# Question: Loop while checking if element in a list in Python
# Question site url: https://stackoverflow.com/questions/35605836
# --------------------------------------
# Result number: 82
# Absolut value of angle between query and result: 0.05447522910216021
# Question: Is there an easy way to get all common module extensions?
# Question site url: https://stackoverflow.com/questions/27569690
# --------------------------------------
# Result number: 83
# Absolut value of angle between query and result: 0.05432321609482331
# Question: Why is this method of testing for palindromes so much slower?
# Question site url: https://stackoverflow.com/questions/34005256
# --------------------------------------
# Result number: 84
# Absolut value of angle between query and result: 0.05426612431581238
# Question: Python import X or from X import Y? (performance)
# Question site url: https://stackoverflow.com/questions/3591962
# --------------------------------------
# Result number: 85
# Absolut value of angle between query and result: 0.05414486361344712
# Question: Is the python "elif" compiled differently from else: if?
# Question site url: https://stackoverflow.com/questions/34304936
# --------------------------------------
# Result number: 86
# Absolut value of angle between query and result: 0.05379539250910188
# Question: How does variable swapping work internally?
# Question site url: https://stackoverflow.com/questions/8587236
# --------------------------------------
# Result number: 87
# Absolut value of angle between query and result: 0.053613602984356544
# Question: Is divmod() faster than using the % and // operators?
# Question site url: https://stackoverflow.com/questions/30079879
# --------------------------------------
# Result number: 88
# Absolut value of angle between query and result: 0.05356435423201742
# Question: What do the zeros in python function bytecode mean?
# Question site url: https://stackoverflow.com/questions/25083861
# --------------------------------------
# Result number: 89
# Absolut value of angle between query and result: 0.05355764305864629
# Question: python2.7.6 Initialize a big dictionary but Memory would be used up
# Question site url: https://stackoverflow.com/questions/34196034
# --------------------------------------
# Result number: 90
# Absolut value of angle between query and result: 0.05351305526459934
# Question: Python buffer copy speed - why is array slower than string?
# Question site url: https://stackoverflow.com/questions/18219718
# --------------------------------------
# Result number: 91
# Absolut value of angle between query and result: 0.05344196287334747
# Question: What is the time complexity of a function lookup operation in Python
# Question site url: https://stackoverflow.com/questions/27792505
# --------------------------------------
# Result number: 92
# Absolut value of angle between query and result: 0.053345586291062896
# Question: Python: multiple assignment vs. individual assignment speed
# Question site url: https://stackoverflow.com/questions/22278695
# --------------------------------------
# Result number: 93
# Absolut value of angle between query and result: 0.05325965936583109
# Question: Should I use elif if I have already returned from the function in a previous block?
# Question site url: https://stackoverflow.com/questions/10599303
# --------------------------------------
# Result number: 94
# Absolut value of angle between query and result: 0.053199579847119906
# Question: While-loop with if-statement faster than while-loop
# Question site url: https://stackoverflow.com/questions/13886258
# --------------------------------------
# Result number: 95
# Absolut value of angle between query and result: 0.05296733525412516
# Question: Python: extra assignments in functions
# Question site url: https://stackoverflow.com/questions/8706661
# --------------------------------------
# Result number: 96
# Absolut value of angle between query and result: 0.052965214284996495
# Question: str performance in python
# Question site url: https://stackoverflow.com/questions/10530315
# --------------------------------------
# Result number: 97
# Absolut value of angle between query and result: 0.05290838754601255
# Question: Why is calling float() on a number slower than adding 0.0 in Python?
# Question site url: https://stackoverflow.com/questions/35229877
# --------------------------------------
# Result number: 98
# Absolut value of angle between query and result: 0.0528423379279384
# Question: Python GIL and globals
# Question site url: https://stackoverflow.com/questions/2157208
# --------------------------------------
# Result number: 99
# Absolut value of angle between query and result: 0.05283583335150536
# Question: Import Module Benchmark
# Question site url: https://stackoverflow.com/questions/39511774
# --------------------------------------
# Result number: 100
# Absolut value of angle between query and result: 0.0527564329296746
# Question: For loop item unpacking
# Question site url: https://stackoverflow.com/questions/23039485
# --------------------------------------
